# %%
import pandas as pd


df = pd.read_csv('03_Library Systembook.csv')

# %%
df.head()
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0  1.0                       Catcher in the Rye   "20/02/2023"    25/02/2023
# 1  2.0          Lord of the rings the two towers  "24/03/2023"    21/03/2023
# 2  3.0  Lord of the rings the return of the kind  "29/03/2023"    25/03/2023
# 3  4.0                                The hobbit  "02/04/2023"    25/03/2023
# 4  5.0                                     Dune   "02/04/2023"    25/03/2023
#
#   Days allowed to borrow  Customer ID
# 0                2 weeks          1.0
# 1                2 weeks          2.0
# 2                2 weeks          3.0
# 3                2 weeks          4.0
# 4                2 weeks          5.0

# %%
df[df.isnull().any(axis=1)]
# Out:
#        Id Books Book checkout Book Returned Days allowed to borrow  \
# 20   21.0   NaN  "01/06/2023"    05/06/2023                2 weeks
# 21    NaN   NaN           NaN           NaN                    NaN
# 22    NaN   NaN           NaN           NaN                    NaN
# 23    NaN   NaN           NaN           NaN                    NaN
# 24    NaN   NaN           NaN           NaN                    NaN
# ..    ...   ...           ...           ...                    ...
# 109   NaN   NaN           NaN           NaN                    NaN
# 110   NaN   NaN           NaN           NaN                    NaN
# 111   NaN   NaN           NaN           NaN                    NaN
# 112   NaN   NaN           NaN           NaN                    NaN
# 113   NaN   NaN           NaN           NaN                    NaN
#
#      Customer ID
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# ..           ...
# 109          NaN
# ...

# %%
df.fillna('n/a')
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  n/a                                       n/a           n/a
# 110  n/a                                       n/a           n/a
# 111  n/a                                       n/a           n/a
# 112  n/a                                       n/a           n/a
# 113  n/a                                       n/a           n/a
#
#     Book Returned Days allowed to borrow Customer ID
# 0      25/02/2023                2 weeks         1.0
# 1      21/03/2023                2 weeks         2.0
# ...

# %%
df_clean = df.dropna(how='all')

# %%
print(df_clean.shape)
# Out:
# (21, 6)

# %%
print(df_clean)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# 9   10.0                              Animal Farm   "20/04/2023"
# 10  11.0                                      1984  "23/04/2023"
# 11  12.0                              Little Women  "02/04/2023"
# 12  13.0                              East of Eden  "30/04/2023"
# ...

# %%
df_clean['Book checkout'] = df_clean['Book checkout'].str.replace('"','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14188\4008603970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Book checkout'] = df_clean['Book checkout'].str.replace('"','')

# %%
print (df_clean)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
# Suggestion

try:
    # Turn to datetime
except Exception as e:
    print("There was an error: ", e)
# Out:
#   Cell In[77], line 5
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 3

# %%
df_clean['Book checkout'] =pd.to_datetime(df_clean['Book checkout'],errors='coerce')
df_clean['Book Returned'] =pd.to_datetime(df_clean['Book Returned'],errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14188\1010391033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Book checkout'] =pd.to_datetime(df_clean['Book checkout'],errors='coerce')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14188\1010391033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Book Returned'] =pd.to_datetime(df_clean['Book Returned'],errors='coerce')

# %%
df_clean.head(n=50)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# 5    6.0                              Little Women    2023-04-02
# 6    7.0                                        IT    2063-04-10
# 7    8.0                                   Misery     2023-04-15
# 8    9.0                                  Catch 22    2023-04-15
# 9   10.0                              Animal Farm     2023-04-20
# 10  11.0                                      1984    2023-04-23
# 11  12.0                              Little Women    2023-04-02
# 12  13.0                              East of Eden    2023-04-30
# ...

# %%
print(df_clean.dtypes)
# Out:
# Id                               float64
# Books                             object
# Book checkout             datetime64[ns]
# Book Returned             datetime64[ns]
# Days allowed to borrow            object
# Customer ID                      float64
# dtype: object

# %%
print (df_clean)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     2023-02-20
# 1    2.0          Lord of the rings the two towers    2023-03-24
# 2    3.0  Lord of the rings the return of the kind    2023-03-29
# 3    4.0                                The hobbit    2023-04-02
# 4    5.0                                     Dune     2023-04-02
# 5    6.0                              Little Women    2023-04-02
# 6    7.0                                        IT    2063-04-10
# 7    8.0                                   Misery     2023-04-15
# 8    9.0                                  Catch 22    2023-04-15
# 9   10.0                              Animal Farm     2023-04-20
# 10  11.0                                      1984    2023-04-23
# 11  12.0                              Little Women    2023-04-02
# 12  13.0                              East of Eden    2023-04-30
# ...

# %%
duplicates = df_clean[df_clean.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Id, Books, Book checkout, Book Returned, Days allowed to borrow, Customer ID]
# Index: []

# %%
print(df_clean.dtypes)
# Out:
# Id                               float64
# Books                             object
# Book checkout             datetime64[ns]
# Book Returned             datetime64[ns]
# Days allowed to borrow            object
# Customer ID                      float64
# dtype: object

# %%
df_clean
